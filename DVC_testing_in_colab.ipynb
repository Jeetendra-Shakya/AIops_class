# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeetendra-Shakya/AIops_class/blob/main/DVC_testing_in_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/expt
# Out:
# /content/drive/MyDrive/Colab Notebooks/expt

# %%
pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/expt'

# %%
# !git clone https://github.com/Jeetendra-Shakya/DVC_DL_Tensorflow_Demo.git
# Out:
# Cloning into 'DVC_DL_Tensorflow_Demo'...
# remote: Enumerating objects: 198, done.
# remote: Counting objects: 100% (198/198), done.
# remote: Compressing objects: 100% (123/123), done.
# remote: Total 198 (delta 104), reused 150 (delta 56), pack-reused 0
# Receiving objects: 100% (198/198), 52.59 MiB | 14.72 MiB/s, done.
# Resolving deltas: 100% (104/104), done.

# %%
# %cd DVC_DL_Tensorflow_Demo/
# Out:
# /content/drive/MyDrive/Colab Notebooks/expt/DVC_DL_Tensorflow_Demo

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/expt/DVC_DL_Tensorflow_Demo

# %%
# !ls
# Out:
# artifacts  dvc.lock  params.yaml  requirements.txt  src
# config	   dvc.yaml  README.md	  setup.py	    src.egg-info

# %%
# !pip install -r requirements.txt
# Out:
# Obtaining file:///content/drive/My%20Drive/Colab%20Notebooks/expt/DVC_DL_Tensorflow_Demo (from -r requirements.txt (line 13))
# ...
#      |████████████████████████████████| 393 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 131 kB 45.9 MB/s
# ...
#      |████████████████████████████████| 306 kB 39.5 MB/s
# ...
#      |████████████████████████████████| 28.5 MB 54 kB/s
# ...
#      |████████████████████████████████| 49 kB 5.9 MB/s
# ...
#      |████████████████████████████████| 125 kB 27.5 MB/s
# ...
#      |████████████████████████████████| 44 kB 2.4 MB/s
# ...
#      |████████████████████████████████| 4.6 MB 40.0 MB/s
# ...
#      |████████████████████████████████| 530 kB 47.4 MB/s
# ...
#      |████████████████████████████████| 48 kB 4.6 MB/s
# ...
#      |████████████████████████████████| 212 kB 44.8 MB/s
# ...
#      |████████████████████████████████| 180 kB 45.6 MB/s
# ...
#      |████████████████████████████████| 296 kB 47.2 MB/s
# ...
#      |████████████████████████████████| 41 kB 36 kB/s
# ...

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/expt/DVC_DL_Tensorflow_Demo

# %%
# !dvc repro -f
# Out:
# Running stage 'prepare_callbacks':
# > python src/stage_03_prepare_callbacks.py --config=config/config.yaml --params=params.yaml
# 2021-10-27 15:44:40.432504: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2021-10-27 15:44:40.432567: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2021-10-27 15:44:40.454015: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1614] Profiler found 1 GPUs
# 2021-10-27 15:44:40.459164: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2021-10-27 15:44:40.459327: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed
# Updating lock file 'dvc.lock'
#
# Running stage 'prepare_base_model':
# > python src/stage_02_prepare_base_model.py --config=config/config.yaml --params=params.yaml
# ...
